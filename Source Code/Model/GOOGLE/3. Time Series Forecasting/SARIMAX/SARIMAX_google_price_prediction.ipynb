# %% [markdown]
# ## Importing All Required Libraries

# %%
pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.10/dist-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (3.0.11)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.5.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.13.1)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (0.14.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.2.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (75.1.0)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.2->pmdarima) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19->pmdarima) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
from datetime import datetime
import time
import warnings
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
from pmdarima.arima import auto_arima
from pmdarima.arima.utils import ndiffs
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error, mean_absolute_error
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Importing Dataset i.e. GOOGLE (GOOGL) Stock Price Dataset

# %%
df = yf.download('GOOGL', start='2004-08-19', end=datetime.today())
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price                     Adj Close     Close      High       Low      Open  \
# Ticker                        GOOGL     GOOGL     GOOGL     GOOGL     GOOGL
# Date
# 2004-08-19 00:00:00+00:00  2.504808  2.511011  2.604104  2.401401  2.502503
# 2004-08-20 00:00:00+00:00  2.703765  2.710460  2.729730  2.515015  2.527778
# 2004-08-23 00:00:00+00:00  2.730976  2.737738  2.839840  2.728979  2.771522
# 2004-08-24 00:00:00+00:00  2.617892  2.624374  2.792793  2.591842  2.783784
# 2004-08-25 00:00:00+00:00  2.646101  2.652653  2.702703  2.599600  2.626627
#
# Price                         Volume
# Ticker                         GOOGL
# Date
# 2004-08-19 00:00:00+00:00  893181924
# 2004-08-20 00:00:00+00:00  456686856
# 2004-08-23 00:00:00+00:00  365122512
# 2004-08-24 00:00:00+00:00  304946748
# 2004-08-25 00:00:00+00:00  183772044

# %%
df.tail()
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                          GOOGL       GOOGL       GOOGL       GOOGL
# Date
# 2024-11-19 00:00:00+00:00  178.119995  178.119995  178.869995  173.559998
# 2024-11-20 00:00:00+00:00  175.979996  175.979996  177.679993  173.779999
# 2024-11-21 00:00:00+00:00  167.630005  167.630005  174.130005  163.699997
# 2024-11-22 00:00:00+00:00  164.759995  164.759995  166.460007  163.899994
# 2024-11-25 00:00:00+00:00  167.039993  167.039993  168.629898  165.607193
#
# Price                            Open    Volume
# Ticker                          GOOGL     GOOGL
# Date
# 2024-11-19 00:00:00+00:00  173.720001  23434900
# 2024-11-20 00:00:00+00:00  177.339996  18997100
# 2024-11-21 00:00:00+00:00  173.899994  59734400
# 2024-11-22 00:00:00+00:00  165.850006  38560400
# 2024-11-25 00:00:00+00:00  166.089996  12933040

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns = df.columns.get_level_values(0)
df
# Out:
# Price                       Adj Close       Close        High         Low  \
# Date
# 2004-08-19 00:00:00+00:00    2.504808    2.511011    2.604104    2.401401
# 2004-08-20 00:00:00+00:00    2.703765    2.710460    2.729730    2.515015
# 2004-08-23 00:00:00+00:00    2.730976    2.737738    2.839840    2.728979
# 2004-08-24 00:00:00+00:00    2.617892    2.624374    2.792793    2.591842
# 2004-08-25 00:00:00+00:00    2.646101    2.652653    2.702703    2.599600
# ...                               ...         ...         ...         ...
# 2024-11-19 00:00:00+00:00  178.119995  178.119995  178.869995  173.559998
# 2024-11-20 00:00:00+00:00  175.979996  175.979996  177.679993  173.779999
# 2024-11-21 00:00:00+00:00  167.630005  167.630005  174.130005  163.699997
# 2024-11-22 00:00:00+00:00  164.759995  164.759995  166.460007  163.899994
# 2024-11-25 00:00:00+00:00  167.039993  167.039993  168.629898  165.607193
#
# Price                            Open     Volume
# Date
# 2004-08-19 00:00:00+00:00    2.502503  893181924
# 2004-08-20 00:00:00+00:00    2.527778  456686856
# 2004-08-23 00:00:00+00:00    2.771522  365122512
# 2004-08-24 00:00:00+00:00    2.783784  304946748
# 2004-08-25 00:00:00+00:00    2.626627  183772044
# ...                               ...        ...
# 2024-11-19 00:00:00+00:00  173.720001   23434900
# 2024-11-20 00:00:00+00:00  177.339996   18997100
# 2024-11-21 00:00:00+00:00  173.899994   59734400
# 2024-11-22 00:00:00+00:00  165.850006   38560400
# 2024-11-25 00:00:00+00:00  166.089996   12933040
#
# [5103 rows x 6 columns]

# %% [markdown]
# ## Copying the dataset for future use

# %%
df.reset_index(inplace=True)
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %% [markdown]
# ### Dropping unwanted column

# %%
df.drop(['Adj Close'], axis=1, inplace=True)

# %%
# Visualize the close price
plt.figure(figsize=(20,6))
plt.plot(df['Close'])
plt.title('Google Stock Price Over Time')
plt.show()

# %% [markdown]
# ### Check the data is stationary or not
# ## ADF test
# We are using Augumented Dickey Fuller (ADF) test to eck if the price series is stationary.
# The null hypothesis of the ADF test is that the time series is non-stationary. So if the p-value of the test is less than the significance level (0.05) than we can reject the null hypothesisband infer that the tim series is indeed stationary.

# %%
# Perform ADF test
result = adfuller(df['Close'].dropna())

print(f'ADF Statistic: {result[0]}')
print(f'p-value: {result[1]}')
print(f'No. of lags used: {result[2]}')
print(f'Number of observations used: {result[3]}')
# Out:
# ADF Statistic: 1.313399807756558
# p-value: 0.9966829185486095
# No. of lags used: 31
# Number of observations used: 5071

# %% [markdown]
# ### Auto-correlation function (ACF)

# %%
# Plot ACF
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 4))
ax1.plot(df['Close'])
ax1.set_title('Original Series')

plot_acf(df['Close'], ax=ax2);

# %% [markdown]
# ## d
# ### Differencing the Data (If Not Stationary)

# %%
diff = df.Close.diff().dropna()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 4))
ax1.plot(diff)
ax1.set_title('Difference once')

plot_acf(diff, ax=ax2);

# %%
diff = df.Close.diff().diff().dropna()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 4))
ax1.plot(diff)
ax1.set_title('Difference twice')

plot_acf(diff, ax=ax2);

# %% [markdown]
# We can use the pmdarima library to get the number of differencing like d required for our model.

# %%
ndiffs(df['Close'], test='adf')
# Out:
# 1

# %% [markdown]
# ## p
# p is the order of the Auto Regressive (AR) term. It refers to the number of lags to be used as predictors.

# %%
diff = df.Close.diff().dropna()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 4))
ax1.plot(diff)
ax1.set_title('Difference once')
ax2.set_ylim(0, 1)
plot_pacf(diff, ax=ax2);

# %% [markdown]
# ## q
# q is the order of the Moving Average (MA) term. It refers to the number of lagged forecast errors that should go into ARIMA model.

# %%
diff = df.Close.diff().dropna()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 4))
ax1.plot(diff)
ax1.set_title('Difference once')
ax2.set_ylim(0, 1)
plot_acf(diff, ax=ax2);

# %% [markdown]
# #Splitting the data into train set and test set

# %%
y = df['Close']
X = df[['Open', 'High', 'Low', 'Volume']]

# %%
# Define the split ratio (e.g., 80% train, 20% test)
split_ratio = 0.8
split_point = int(len(df) * split_ratio)

# Training and testing sets for target and features
y_train, y_test = y[:split_point], y[split_point:]
X_train, X_test = X[:split_point], X[split_point:]

# %%
plt.figure(figsize=(20,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(y_train, 'green', label='Train data')
plt.plot(y_test, 'blue', label='Test data')
plt.legend()

# %% [markdown]
# ### For p, d, q we can use the above method observing the plots of ACF and PACF but now we are going to use Auto ARIMA to get the best parameters without even plotting ACF and PACF graphs.
#
# Auto ARIMA: Automatically discover the optimal order for an ARIMA model.
#
# The auto_arima function seeks to identify the most optimal parameters for an ARIMA model, and returns a fitted ARIMA model. This function is based on the commonly-used R function, forecast::auto.arima.

# %%
model_autoARIMA = auto_arima(df.Close, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0,
                      D=0,
                      trace=True,
                      error_action='ignore',
                      suppress_warnings=True,
                      stepwise=True)
print(model_autoARIMA.summary())
model_autoARIMA.plot_diagnostics(figsize=(20,8))
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=16259.952, Time=0.57 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=16259.395, Time=1.36 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=16259.249, Time=2.06 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=16261.696, Time=0.30 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=16246.343, Time=7.67 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=16247.163, Time=9.23 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=16247.271, Time=3.45 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=16257.102, Time=0.93 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=16257.919, Time=0.74 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=16250.338, Time=7.40 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=16249.931, Time=1.03 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0] intercept
# Total fit time: 34.921 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 5103
# Model:               SARIMAX(1, 1, 1)   Log Likelihood               -8119.171
# Date:                Mon, 25 Nov 2024   AIC                          16246.343
# Time:                        18:11:59   BIC                          16272.492
# Sample:                             0   HQIC                         16255.498
#                                - 5103
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0058      0.003      2.154      0.031       0.001       0.011
# ar.L1          0.8202      0.036     22.853      0.000       0.750       0.891
# ma.L1         -0.8539      0.033    -26.164      0.000      -0.918      -0.790
# sigma2         1.4118      0.008    172.544      0.000       1.396       1.428
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.34   Jarque-Bera (JB):             97441.63
# Prob(Q):                              0.56   Prob(JB):                         0.00
# Heteroskedasticity (H):              72.18   Skew:                            -0.15
# Prob(H) (two-sided):                  0.00   Kurtosis:                        24.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### Now fitting the model

# %%
model = SARIMAX(y_train, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), exog=X_train)
start = time.time()
fitted_model = model.fit(disp=False)
end = time.time()
print('Training Time: ', end - start)

# Print model summary
print(fitted_model.summary())
# Out:
# Training Time:  31.703407526016235
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Close   No. Observations:                 4082
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                -397.871
# Date:                            Mon, 25 Nov 2024   AIC                            813.742
# Time:                                    18:12:32   BIC                            870.542
# Sample:                                         0   HQIC                           833.858
#                                            - 4082
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Open          -0.5996      0.001   -713.244      0.000      -0.601      -0.598
# High           0.7602      0.001    983.944      0.000       0.759       0.762
# Low            0.7331      0.001    831.461      0.000       0.731       0.735
# Volume      2.982e-11   1.13e-10      0.264      0.792   -1.91e-10    2.51e-10
# ar.L1         -0.2102      0.000   -966.617      0.000      -0.211      -0.210
# ma.L1         -0.6415      0.000  -2012.480      0.000      -0.642      -0.641
# ar.S.L12      -0.2777   1.87e-05  -1.49e+04      0.000      -0.278      -0.278
# ma.S.L12      -0.4168   2.19e-05   -1.9e+04      0.000      -0.417      -0.417
# sigma2         0.0994      0.001     94.223      0.000       0.097       0.101
# ===================================================================================
# Ljung-Box (L1) (Q):                  29.92   Jarque-Bera (JB):             87158.52
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              16.14   Skew:                            -0.35
# Prob(H) (two-sided):                  0.00   Kurtosis:                        25.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 9.26e+19. Standard errors may be unstable.

# %%
forecast = fitted_model.predict(start=len(y_train), end=len(y_train) + len(y_test) - 1, exog=X_test)

# Print forecasted values
forecast
# Out:
# 4082     86.530477
# 4083     86.756290
# 4084     86.625608
# 4085     87.946103
# 4086     86.787266
#            ...
# 5098    178.957556
# 5099    176.425730
# 5100    168.030677
# 5101    167.701548
# 5102    169.966858
# Name: predicted_mean, Length: 1021, dtype: float64

# %%
y_test
# Out:
# Date
# 2020-11-04 00:00:00+00:00     87.292503
# 2020-11-05 00:00:00+00:00     88.125000
# 2020-11-06 00:00:00+00:00     87.986504
# 2020-11-09 00:00:00+00:00     88.070999
# 2020-11-10 00:00:00+00:00     86.886002
#                                 ...
# 2024-11-19 00:00:00+00:00    178.119995
# 2024-11-20 00:00:00+00:00    175.979996
# 2024-11-21 00:00:00+00:00    167.630005
# 2024-11-22 00:00:00+00:00    164.759995
# 2024-11-25 00:00:00+00:00    167.039993
# Name: Close, Length: 1021, dtype: float64

# %%
# Plot the results
plt.figure(figsize=(20, 6))
plt.plot(y_train, label='Train Data')
plt.plot(y_test, label='Actual Test Data', color='green')
plt.plot(y_test.index, forecast, label='SARIMAX Forecast', color='red')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.title('SARIMAX Model - Actual vs. Forecasted Stock Prices (first 80% train)')
plt.legend()
plt.show()

# %%
mse = mean_squared_error(y_test, forecast)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, forecast)
print('Mean Squared Error:', mse)
print('Root Mean Squared Error:', rmse)
print('Mean Absolute Error:', mae)
# Out:
# Mean Squared Error: 9.484298873951975
# Root Mean Squared Error: 3.0796588892200343
# Mean Absolute Error: 2.6890549988365864
