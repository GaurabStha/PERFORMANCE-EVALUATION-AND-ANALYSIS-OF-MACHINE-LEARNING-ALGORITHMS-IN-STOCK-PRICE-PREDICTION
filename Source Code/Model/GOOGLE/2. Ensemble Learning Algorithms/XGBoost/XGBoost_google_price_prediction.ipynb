# %% [markdown]
# ## Importing All Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
from datetime import datetime
import time
import warnings
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Importing Dataset i.e. GOOGLE (GOOGL) Stock Price Dataset

# %%
df = yf.download('GOOGL', start='2004-08-19', end=datetime.today())
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price                     Adj Close     Close      High       Low      Open  \
# Ticker                        GOOGL     GOOGL     GOOGL     GOOGL     GOOGL
# Date
# 2004-08-19 00:00:00+00:00  2.504808  2.511011  2.604104  2.401401  2.502503
# 2004-08-20 00:00:00+00:00  2.703765  2.710460  2.729730  2.515015  2.527778
# 2004-08-23 00:00:00+00:00  2.730976  2.737738  2.839840  2.728979  2.771522
# 2004-08-24 00:00:00+00:00  2.617892  2.624374  2.792793  2.591842  2.783784
# 2004-08-25 00:00:00+00:00  2.646101  2.652653  2.702703  2.599600  2.626627
#
# Price                         Volume
# Ticker                         GOOGL
# Date
# 2004-08-19 00:00:00+00:00  893181924
# 2004-08-20 00:00:00+00:00  456686856
# 2004-08-23 00:00:00+00:00  365122512
# 2004-08-24 00:00:00+00:00  304946748
# 2004-08-25 00:00:00+00:00  183772044

# %%
df.tail()
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                          GOOGL       GOOGL       GOOGL       GOOGL
# Date
# 2024-11-18 00:00:00+00:00  175.300003  175.300003  175.440002  172.899994
# 2024-11-19 00:00:00+00:00  178.119995  178.119995  178.869995  173.559998
# 2024-11-20 00:00:00+00:00  175.979996  175.979996  177.679993  173.779999
# 2024-11-21 00:00:00+00:00  167.630005  167.630005  174.130005  163.699997
# 2024-11-22 00:00:00+00:00  164.759995  164.759995  166.460007  163.899994
#
# Price                            Open    Volume
# Ticker                          GOOGL     GOOGL
# Date
# 2024-11-18 00:00:00+00:00  173.419998  20206600
# 2024-11-19 00:00:00+00:00  173.720001  23434900
# 2024-11-20 00:00:00+00:00  177.339996  18997100
# 2024-11-21 00:00:00+00:00  173.899994  59734400
# 2024-11-22 00:00:00+00:00  165.850006  38560400

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns = df.columns.get_level_values(0)
df
# Out:
# Price                       Adj Close       Close        High         Low  \
# Date
# 2004-08-19 00:00:00+00:00    2.504808    2.511011    2.604104    2.401401
# 2004-08-20 00:00:00+00:00    2.703765    2.710460    2.729730    2.515015
# 2004-08-23 00:00:00+00:00    2.730976    2.737738    2.839840    2.728979
# 2004-08-24 00:00:00+00:00    2.617892    2.624374    2.792793    2.591842
# 2004-08-25 00:00:00+00:00    2.646101    2.652653    2.702703    2.599600
# ...                               ...         ...         ...         ...
# 2024-11-18 00:00:00+00:00  175.300003  175.300003  175.440002  172.899994
# 2024-11-19 00:00:00+00:00  178.119995  178.119995  178.869995  173.559998
# 2024-11-20 00:00:00+00:00  175.979996  175.979996  177.679993  173.779999
# 2024-11-21 00:00:00+00:00  167.630005  167.630005  174.130005  163.699997
# 2024-11-22 00:00:00+00:00  164.759995  164.759995  166.460007  163.899994
#
# Price                            Open     Volume
# Date
# 2004-08-19 00:00:00+00:00    2.502503  893181924
# 2004-08-20 00:00:00+00:00    2.527778  456686856
# 2004-08-23 00:00:00+00:00    2.771522  365122512
# 2004-08-24 00:00:00+00:00    2.783784  304946748
# 2004-08-25 00:00:00+00:00    2.626627  183772044
# ...                               ...        ...
# 2024-11-18 00:00:00+00:00  173.419998   20206600
# 2024-11-19 00:00:00+00:00  173.720001   23434900
# 2024-11-20 00:00:00+00:00  177.339996   18997100
# 2024-11-21 00:00:00+00:00  173.899994   59734400
# 2024-11-22 00:00:00+00:00  165.850006   38560400
#
# [5102 rows x 6 columns]

# %% [markdown]
# ## Copying the dataset for future use

# %%
df1 = df.copy()
df1.reset_index(inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Dropping unwanted column

# %%
df.drop(['Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Splitting into features and target

# %%
X = df.drop(['Close'], axis=1)
y = df['Close']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
X = scaler.fit_transform(X)

# %% [markdown]
# ### Splitting the data into train and test set

# %%
X_train, X_test, y_train, y_test = X[:round(X.shape[0]*0.8)], X[round(X.shape[0]*0.8):], y[:round(y.shape[0]*0.8)], y[round(y.shape[0]*0.8):]

# %% [markdown]
# ### Model Building using Random Forest Regression

# %%
model = XGBRegressor(n_estimators=100, max_depth=10, learning_rate=0.05, random_state=42)
start = time.time()
model.fit(X_train, y_train)
end = time.time()
print('Training Time:', end-start)
# Out:
# Training Time: 1.8465330600738525

# %%
model.score(X_train, y_train)
# Out:
# 0.9998667266609712

# %%
predicted = model.predict(X_test)
predicted
# Out:
# array([80.554535, 80.48934 , 80.50159 , ..., 80.437195, 80.655945,
#        80.48934 ], dtype=float32)

# %%
prediction = pd.DataFrame({'Date': df1.Date[round(df.shape[0]*0.8):], 'Actual': y_test, 'Predicted': predicted})
prediction.set_index('Date', inplace=True)
prediction
# Out:
#                                Actual  Predicted
# Date
# 2020-11-04 00:00:00+00:00   87.292503  80.554535
# 2020-11-05 00:00:00+00:00   88.125000  80.489342
# 2020-11-06 00:00:00+00:00   87.986504  80.501587
# 2020-11-09 00:00:00+00:00   88.070999  80.744209
# 2020-11-10 00:00:00+00:00   86.886002  80.057671
# ...                               ...        ...
# 2024-11-18 00:00:00+00:00  175.300003  80.437195
# 2024-11-19 00:00:00+00:00  178.119995  80.819389
# 2024-11-20 00:00:00+00:00  175.979996  80.437195
# 2024-11-21 00:00:00+00:00  167.630005  80.655945
# 2024-11-22 00:00:00+00:00  164.759995  80.489342
#
# [1020 rows x 2 columns]

# %%
plt.figure(figsize=(18, 5))
plt.plot(prediction.Actual, label='Actual', color='g', linewidth=1)
plt.plot(prediction.Predicted, label='Predicted', color='r', linewidth=1)
plt.legend()
plt.show()

# %%
model.predict(scaler.transform([[165.86, 167.65, 165.24, 3621520]]))
# Out:
# array([80.437195], dtype=float32)

# %%
df1[df1.Date == '2004-09-01']
# Out:
# Price                      Date  Adj Close     Close      High       Low  \
# 9     2004-09-01 00:00:00+00:00   2.502562  2.508759  2.576827  2.494244
#
# Price     Open     Volume
# 9      2.57007  182765052

# %%
model.predict(scaler.transform([[2.57007, 2.576827, 2.494244, 182765052]]))
# Out:
# array([2.8287156], dtype=float32)

# %% [markdown]
# ## Calculating the Performance Evaluation Metrics

# %%
mse = mean_squared_error(y_test, predicted)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, predicted)
print('Mean Squared Error:', mse)
print('Root Mean Squared Error:', rmse)
print('Mean Absolute Error:', mae)
# Out:
# Mean Squared Error: 2831.101995043933
# Root Mean Squared Error: 53.20810084041652
# Mean Absolute Error: 46.84224714391372

# %% [markdown]
# ### Here the performance metrics are too much higher so, we have to tune the hyperparameters.

# %%
model_params = {
    'n_estimators': [5, 10, 100, 200],
    'max_depth': [10, 20, 30],
    'learning_rate': [0.01, 0.05, 0.1, 0.2]
    }

grid_search = GridSearchCV(XGBRegressor(random_state=42), model_params, cv=5, return_train_score=False)
start = time.time()
grid_search.fit(X_train, y_train)
end = time.time()
print('Training Time:', end-start)
# Out:
# Training Time: 131.43039274215698

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.2, 'max_depth': 30, 'n_estimators': 100}

# %%
grid_search.best_score_
# Out:
# 0.22427820951371746

# %%
grid_search_prediction = grid_search.predict(X_test)
grid_search_prediction
# Out:
# array([80.80615, 81.34229, 80.99138, ..., 82.11604, 81.47278, 81.01249],
#       dtype=float32)

# %%
prediction = pd.DataFrame({'Date': df1.Date[round(df.shape[0]*0.8):], 'Actual': y_test, 'Predicted': grid_search_prediction})
prediction.set_index('Date', inplace=True)
prediction
# Out:
#                                Actual  Predicted
# Date
# 2020-11-04 00:00:00+00:00   87.292503  80.806152
# 2020-11-05 00:00:00+00:00   88.125000  81.342293
# 2020-11-06 00:00:00+00:00   87.986504  80.991379
# 2020-11-09 00:00:00+00:00   88.070999  81.473145
# 2020-11-10 00:00:00+00:00   86.886002  81.090141
# ...                               ...        ...
# 2024-11-18 00:00:00+00:00  175.300003  82.116043
# 2024-11-19 00:00:00+00:00  178.119995  79.455956
# 2024-11-20 00:00:00+00:00  175.979996  82.116043
# 2024-11-21 00:00:00+00:00  167.630005  81.472778
# 2024-11-22 00:00:00+00:00  164.759995  81.012489
#
# [1020 rows x 2 columns]

# %%
plt.figure(figsize=(18, 5))
plt.plot(prediction.Actual, label='Actual', color='g', linewidth=1)
plt.plot(prediction.Predicted, label='Predicted', color='r', linewidth=1)
plt.title('Actual vs Predicted Close Price (Google - First 80% data training)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Evaluation Metrics after Hyperparameter Tuning

# %%
mse = mean_squared_error(y_test, grid_search_prediction)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, grid_search_prediction)
print('Mean Squared Error:', mse)
print('Root Mean Squared Error:', rmse)
print('Mean Absolute Error:', mae)
# Out:
# Mean Squared Error: 2773.901539359981
# Root Mean Squared Error: 52.66784160529062
# Mean Absolute Error: 46.262078790103686
