# %% [markdown]
# ## Importing All Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
from datetime import datetime
import time
import warnings
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Importing Dataset i.e. GOOGLE (GOOGL) Stock Price Dataset

# %%
df = yf.download('GOOGL', start='2004-08-19', end=datetime.today())
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price                     Adj Close     Close      High       Low      Open  \
# Ticker                        GOOGL     GOOGL     GOOGL     GOOGL     GOOGL
# Date
# 2004-08-19 00:00:00+00:00  2.504808  2.511011  2.604104  2.401401  2.502503
# 2004-08-20 00:00:00+00:00  2.703765  2.710460  2.729730  2.515015  2.527778
# 2004-08-23 00:00:00+00:00  2.730976  2.737738  2.839840  2.728979  2.771522
# 2004-08-24 00:00:00+00:00  2.617892  2.624374  2.792793  2.591842  2.783784
# 2004-08-25 00:00:00+00:00  2.646101  2.652653  2.702703  2.599600  2.626627
#
# Price                         Volume
# Ticker                         GOOGL
# Date
# 2004-08-19 00:00:00+00:00  893181924
# 2004-08-20 00:00:00+00:00  456686856
# 2004-08-23 00:00:00+00:00  365122512
# 2004-08-24 00:00:00+00:00  304946748
# 2004-08-25 00:00:00+00:00  183772044

# %%
df.tail()
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                          GOOGL       GOOGL       GOOGL       GOOGL
# Date
# 2024-11-18 00:00:00+00:00  175.300003  175.300003  175.440002  172.899994
# 2024-11-19 00:00:00+00:00  178.119995  178.119995  178.869995  173.559998
# 2024-11-20 00:00:00+00:00  175.979996  175.979996  177.679993  173.779999
# 2024-11-21 00:00:00+00:00  167.630005  167.630005  174.130005  163.699997
# 2024-11-22 00:00:00+00:00  164.759995  164.759995  166.460007  163.899994
#
# Price                            Open    Volume
# Ticker                          GOOGL     GOOGL
# Date
# 2024-11-18 00:00:00+00:00  173.419998  20206600
# 2024-11-19 00:00:00+00:00  173.720001  23434900
# 2024-11-20 00:00:00+00:00  177.339996  18997100
# 2024-11-21 00:00:00+00:00  173.899994  59734400
# 2024-11-22 00:00:00+00:00  165.850006  38560400

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns = df.columns.get_level_values(0)

# %% [markdown]
# ## Copying the dataset for future use

# %%
df1 = df.copy()
df1.reset_index(inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Dropping unwanted column

# %%
df.drop(['Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Splitting into features and target

# %%
X = df.drop(['Close'], axis=1)
y = df['Close']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# ### Splitting the data into train and test set

# %%
X_train, X_test, y_train, y_test = X[:round(X.shape[0]*0.8)], X[round(X.shape[0]*0.8):], y[:round(y.shape[0]*0.8)], y[round(y.shape[0]*0.8):]

# %% [markdown]
# ### Model Building using Linear Regression

# %%
model = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=0.01)
start = time.time()
model.fit(X_train, y_train)
end = time.time()
print('Training Time:', end-start)
# Out:
# Training Time: 2.3933520317077637

# %%
model.score(X_train, y_train)
# Out:
# 0.9997964953766131

# %%
predicted = model.predict(X_test)
predicted
# Out:
# array([ 85.93544319,  87.60215722,  86.89660181, ..., 156.47659326,
#        152.64939554, 149.96798848])

# %%
prediction = pd.DataFrame({'Date': df1.Date[round(df.shape[0]*0.8):], 'Actual': y_test, 'Predicted': predicted})
prediction.set_index('Date', inplace=True)
prediction
# Out:
#                                Actual   Predicted
# Date
# 2020-11-04 00:00:00+00:00   87.292503   85.935443
# 2020-11-05 00:00:00+00:00   88.125000   87.602157
# 2020-11-06 00:00:00+00:00   87.986504   86.896602
# 2020-11-09 00:00:00+00:00   88.070999   88.637974
# 2020-11-10 00:00:00+00:00   86.886002   86.156260
# ...                               ...         ...
# 2024-11-18 00:00:00+00:00  175.300003  155.403093
# 2024-11-19 00:00:00+00:00  178.119995  156.488803
# 2024-11-20 00:00:00+00:00  175.979996  156.476593
# 2024-11-21 00:00:00+00:00  167.630005  152.649396
# 2024-11-22 00:00:00+00:00  164.759995  149.967988
#
# [1020 rows x 2 columns]

# %%
plt.figure(figsize=(18, 5))
plt.plot(prediction.Actual, label='Actual', color='g', linewidth=1)
plt.plot(prediction.Predicted, label='Predicted', color='r', linewidth=1)
plt.legend()
plt.show()

# %%
model.predict(scaler.transform([[165.86, 167.65, 165.24, 3621520]]))
# Out:
# array([150.7258976])

# %%
df1[df1.Date == '2004-09-01']
# Out:
# Price                      Date  Adj Close     Close      High       Low  \
# 9     2004-09-01 00:00:00+00:00   2.502562  2.508759  2.576827  2.494244
#
# Price     Open     Volume
# 9      2.57007  182765052

# %%
model.predict(scaler.transform([[2.57007, 2.576827, 2.494244, 182765052]]))
# Out:
# array([2.66942051])

# %% [markdown]
# ## Calculating the Performance Evaluation Metrics

# %%
mse = mean_squared_error(y_test, predicted)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, predicted)
print('Mean Squared Error:', mse)
print('Root Mean Squared Error:', rmse)
print('Mean Absolute Error:', mae)
# Out:
# Mean Squared Error: 73.12390897837405
# Root Mean Squared Error: 8.551251895387836
# Mean Absolute Error: 6.595552680781163

# %% [markdown]
# ### Here the performance metrics are too much higher so, we have to tune the hyperparameters.

# %%
model_params = {
            'C': [0.1, 1, 10, 100, 1000],
            'kernel': ['rbf','linear', 'poly', 'sigmoid'],
            'gamma': [0.01, 0.1, 1, 'auto']
            }


grid_search = GridSearchCV(SVR(), model_params, cv=5, return_train_score=False)
start = time.time()
grid_search.fit(X_train, y_train)
end = time.time()
print('Training Time:', end-start)
# Out:
# Training Time: 227.20879292488098

# %%
grid_search.best_params_
# Out:
# {'C': 1000, 'gamma': 0.01, 'kernel': 'linear'}

# %%
grid_search.best_score_
# Out:
# 0.9990085644126335

# %%
grid_search_prediction = grid_search.predict(X_test)
grid_search_prediction
# Out:
# array([ 87.72946572,  88.27125042,  87.7236718 , ..., 174.98482469,
#        166.3144148 , 164.94096198])

# %%
prediction = pd.DataFrame({'Date': df1.Date[round(df.shape[0]*0.8):], 'Actual': y_test, 'Predicted': grid_search_prediction})
prediction.set_index('Date', inplace=True)
prediction
# Out:
#                                Actual   Predicted
# Date
# 2020-11-04 00:00:00+00:00   87.292503   87.729466
# 2020-11-05 00:00:00+00:00   88.125000   88.271250
# 2020-11-06 00:00:00+00:00   87.986504   87.723672
# 2020-11-09 00:00:00+00:00   88.070999   89.182444
# 2020-11-10 00:00:00+00:00   86.886002   87.164655
# ...                               ...         ...
# 2024-11-18 00:00:00+00:00  175.300003  174.714289
# 2024-11-19 00:00:00+00:00  178.119995  177.711906
# 2024-11-20 00:00:00+00:00  175.979996  174.984825
# 2024-11-21 00:00:00+00:00  167.630005  166.314415
# 2024-11-22 00:00:00+00:00  164.759995  164.940962
#
# [1020 rows x 2 columns]

# %%
plt.figure(figsize=(18, 5))
plt.plot(prediction.Actual, label='Actual', color='g', linewidth=1)
plt.plot(prediction.Predicted, label='Predicted', color='r', linewidth=1)
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Evaluation Metrics after Hyperparameter Tuning

# %%
mse = mean_squared_error(y_test, grid_search_prediction)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, grid_search_prediction)
print('Mean Squared Error:', mse)
print('Root Mean Squared Error:', rmse)
print('Mean Absolute Error:', mae)
# Out:
# Mean Squared Error: 0.660863283451116
# Root Mean Squared Error: 0.8129349810723586
# Mean Absolute Error: 0.6302780443367378
