# %% [markdown]
# ## Importing All Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
from datetime import datetime
import warnings
import time
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Importing Dataset i.e. GOOGLE (GOOGL) Stock Price Dataset

# %%
df = yf.download('GOOGL', start='2004-08-19', end=datetime.today())
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price                     Adj Close     Close      High       Low      Open  \
# Ticker                        GOOGL     GOOGL     GOOGL     GOOGL     GOOGL
# Date
# 2004-08-19 00:00:00+00:00  2.504808  2.511011  2.604104  2.401401  2.502503
# 2004-08-20 00:00:00+00:00  2.703765  2.710460  2.729730  2.515015  2.527778
# 2004-08-23 00:00:00+00:00  2.730976  2.737738  2.839840  2.728979  2.771522
# 2004-08-24 00:00:00+00:00  2.617892  2.624374  2.792793  2.591842  2.783784
# 2004-08-25 00:00:00+00:00  2.646101  2.652653  2.702703  2.599600  2.626627
#
# Price                         Volume
# Ticker                         GOOGL
# Date
# 2004-08-19 00:00:00+00:00  893181924
# 2004-08-20 00:00:00+00:00  456686856
# 2004-08-23 00:00:00+00:00  365122512
# 2004-08-24 00:00:00+00:00  304946748
# 2004-08-25 00:00:00+00:00  183772044

# %%
df.tail()
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                          GOOGL       GOOGL       GOOGL       GOOGL
# Date
# 2024-11-22 00:00:00+00:00  164.759995  164.759995  166.460007  163.899994
# 2024-11-25 00:00:00+00:00  167.649994  167.649994  168.630005  165.610001
# 2024-11-26 00:00:00+00:00  169.119995  169.119995  169.820007  167.580002
# 2024-11-27 00:00:00+00:00  169.229996  169.229996  169.479996  168.020004
# 2024-11-29 00:00:00+00:00  168.949997  168.949997  169.429993  167.160004
#
# Price                            Open    Volume
# Ticker                          GOOGL     GOOGL
# Date
# 2024-11-22 00:00:00+00:00  165.850006  38604600
# 2024-11-25 00:00:00+00:00  166.089996  33135300
# 2024-11-26 00:00:00+00:00  167.630005  20486700
# 2024-11-27 00:00:00+00:00  169.000000  19266500
# 2024-11-29 00:00:00+00:00  168.500000  14257200

# %%
df.columns = df.columns.get_level_values(0)

# %%
def load_data(filepath):
    # Load the dataset
    data = pd.read_csv(filepath)
    # Assuming the dataset has a 'Close' column
    prices = data['Close'].values
    # Normalize data
    prices = (prices - np.mean(prices)) / np.std(prices)
    # Feature matrix (adding a bias term)
    X = np.arange(len(prices)).reshape(-1, 1)
    X = np.c_[np.ones(X.shape[0]), X]  # Add bias term
    y = prices
    return X, y

# %%
class LinearRegression:
    def __init__(self, learning_rate=0.01, num_iterations=1000):
        self.learning_rate = learning_rate
        self.num_iterations = num_iterations
        self.weights = None

    def fit(self, X, y):
        self.weights = np.zeros(X.shape[1])
        m = X.shape[0]

        for i in range(self.iterations):
            predictions = np.dot(X, self.weights)
            error = predictions - y
            gradient = (1 / m) * np.dot(X.T, error)
            self.weights -= self.learning_rate * gradient
